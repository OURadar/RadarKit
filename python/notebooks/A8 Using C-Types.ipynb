# %% [markdown]
# # Using CTypes
#
# If `libradarkit.so` is readily accessible, one can call the pre-compiled C functions through `ctypes`

# %%
import ctypes

rk = ctypes.CDLL('../../libradarkit.so')

# %%
rk.RKTestByNumber(0)
# Out:
# ===============
# RKShowTypeSizes
# ===============
# sizeof(void *) = 8
# sizeof(char) = 1
# sizeof(short) = 2
# sizeof(int) = 4
# sizeof(long) = 8
# sizeof(long long) = 8
# sizeof(unsigned char) = 1
# sizeof(unsigned short) = 2
# sizeof(unsigned int) = 4
# sizeof(unsigned long) = 8
# sizeof(unsigned long long) = 8
# sizeof(size_t) = 8
# sizeof(ssize_t) = 8
# sizeof(bool) = 1
# sizeof(int8_t) = 1
# sizeof(uint8_t) = 1
# sizeof(int16_t) = 2
# sizeof(uint16_t) = 2
# sizeof(int32_t) = 4
# sizeof(uint32_t) = 4
# sizeof(int64_t) = 8
# sizeof(uint64_t) = 8
# sizeof(struct sockaddr) = 16
# sizeof(struct sockaddr_in) = 16
# sizeof(RKInitFlag) = 4
# sizeof(RKStatusFlag) = 4
# sizeof(RKHealthFlag) = 4
# sizeof(RKPositionFlag) = 4
# sizeof(RKPulseStatus) = 4
# sizeof(RKRayStatus) = 4
# sizeof(RKEngineState) = 4
# sizeof(RKStatusEnum) = 4
# sizeof(RKBaseProductList) = 4
# sizeof(RKStream) = 8
# sizeof(RKByte) = 1
# sizeof(RKFloat) = 4
# sizeof(RKInt16C) = 4
# sizeof(RKComplex) = 8
# sizeof(RKVec) = 16
# sizeof(RKRadarDesc) = 1,072
# sizeof(RKConfig) = 1,024
# sizeof(RKHealth) = 4,132
# sizeof(RKNodalHealth) = 13
# sizeof(RKPosition) = 128
# sizeof(RKPulseHeader) = 192
# sizeof(RKPulseHeaderV1) = 106
# sizeof(RKPulseParameters) = 140
# sizeof(pulse->headerBytes) = 384   SIMDAlign = True
# sizeof(RKPulse) = 384   SIMDAlign = True
# sizeof(RKRayHeader) = 124
# sizeof(RKRayHeaderV1) = 120
# sizeof(ray->headerBytes) = 128   SIMDAlign = True
# sizeof(RKSweep) = 15,095
# sizeof(sweep->header) = 3,087
# sizeof(RKPreferenceObject) = 4,778
# sizeof(RKControl) = 646
# sizeof(RKStatus) = 123
# sizeof(RKFileMonitor) = 1,185
# sizeof(RKFilterAnchor) = 64
# sizeof(RKWaveform) = 11,791
# sizeof(RKFileHeader) = 4,096
# sizeof(RKWaveFileGlobalHeader) = 512
# sizeof(RKWaveformCalibration) = 261
# sizeof(RKSweepHeader) = 3,087
# sizeof(RKProductDesc) = 1,024
# sizeof(RKProductHeader) = 2,082
#
# RKFilterAnchorDefault:
# .name = 0
# .origin = 0
# .length = 1
# .inputOrigin = 0
# .outputOrigin = 0
# .maxDataLength = 262,144
# .subCarrierFrequency = 0.000
# .sensitivityGain = 0.000 dB
# .filterGain = 1.000 dB
# .fullScale = 0.000
#
# RKFilterAnchorDefaultWithMaxDataLength(1000):
# .name = 0
# .origin = 0
# .length = 1
# .inputOrigin = 0
# .outputOrigin = 0
# .maxDataLength = 1,000
# .subCarrierFrequency = 0.000
# .sensitivityGain = 0.000 dB
# .filterGain = 1.000 dB
# .fullScale = 0.000
#
# RKResultSuccess                                    0
# RKResultTooBig                                     1
# RKResultTimeout                                    2
# RKResultNullInput                                  3
# RKResultEngineNotWired                             4
# RKResultEngineNotActive                            5
# RKResultIncompleteSend                             6
# RKResultIncompleteReceive                          7
# RKResultIncompleteTransceiver                      8
# RKResultIncompletePedestal                         9
# RKResultIncompleteHealthRelay                     10
# RKResultIncompleteControl                         11
# RKResultIncompleteWaveformCalibration             12
# RKResultIncompleteProductDescription              13
# RKResultIncompleteScanDescription                 14
# RKResultErrorCreatingOperatorRoutine              15
# RKResultErrorCreatingOperatorCommandRoutine       16
# RKResultErrorCreatingClientRoutine                17
# RKResultSDToFDError                               18
# RKResultNoPulseBuffer                             19
# RKResultNoRayBuffer                               20
# RKResultNoPulseCompressionEngine                  21
# RKResultNoPulseRingEngine                         22
# RKResultNoMomentEngine                            23
# RKResultFailedToStartCompressionCore              24
# RKResultFailedToStartRingCore                     25
# RKResultFailedToStartPulseWatcher                 26
# RKResultFailedToStartRingPulseWatcher             27
# RKResultFailedToInitiateSemaphore                 28
# RKResultFailedToRetrieveSemaphore                 29
# RKResultFailedToAllocateFFTSpace                  30
# RKResultFailedToAllocateFilter                    31
# RKResultFailedToAllocateDutyCycleBuffer           32
# RKResultFailedToAllocateScratchSpace              33
# RKResultFailedToSetWaveform                       34
# RKResultFailedToSetFilter                         35
# RKResultEngineDeactivatedMultipleTimes            36
# RKResultFailedToStartMomentCore                   37
# RKResultFailedToStartPulseGatherer                38
# RKResultUnableToChangeCoreCounts                  39
# RKResultFailedToStartPedestalWorker               40
# RKResultFailedToGetVacantPosition                 41
# RKResultFailedToGetVacantHealth                   42
# RKResultFailedToStartRayGatherer                  43
# RKResultFailedToStartHealthWorker                 44
# 61
# RKResultFailedToStartPulseRecorder                45
# RKResultFailedToStartPedestalMonitor              46
# RKResultFailedToStartpedestalVcpEngine            47
# RKResultFailedToStartFileManager                  48
# RKResultFailedToStartFileRemover                  49
# RKResultFailedToStartTransceiver                  50
# RKResultFailedToStartPedestal                     51
# RKResultFailedToStartHealthRelay                  52
# RKResultPreferenceFileNotFound                    53
# RKResultPreferenceKeywordNotFound                 54
# RKResultFailedToMeasureNoise                      55
# RKResultFailedToEstimateNoise                     56
# RKResultFailedToCreateFileRemover                 57
# RKResultFileManagerBufferNotResuable              58
# RKResultInvalidMomentParameters                   59
# RKResultFailedToCreateUnitWorker                  60
# RKResultFailedToStartHostWatcher                  61
# RKResultFailedToStartHostPinger                   62
# RKResultFailedToExecuteCommand                    63
# RKResultFailedToSetVCP                            64
# RKResultFailedToAddHost                           65
# RKResultFailedToFindProductId                     66
# RKResultFailedToOpenFileForProduct                67
# RKResultClientNotConnected                        68
# RKResultFileManagerInconsistentFolder             69
# RKResultFailedToExpandWaveform                    70
# RKResultFailedToOpenFileForWriting                71
# RKResultRadarNotLive                              72
# RKResultRawDataTypeUndefined                      73
# RKResultNothingToRead                             74
# RKResultNoRadar                                   75
#
# RKMomentIndexCount = 26
# RKBaseProductIndexCount = 19
#
# ==============================
# RKNetworkShowPacketTypeNumbers
# ==============================
# RKNetworkPacketTypeProcessorStatus = 9
# RKNetworkPacketTypeRayDisplay = 109
# RKNetworkPacketTypeAlertMessage = 110
# RKNetworkPacketTypeConfig = 111
# RKNetworkPacketTypeSweep = 112
# RKNetworkPacketTypeSweepHeader = 113
# RKNetworkPacketTypeSweepRay = 114

# %%
RKIntegerToCommaStyleString = rk.RKIntegerToCommaStyleString
RKIntegerToCommaStyleString.restype = ctypes.POINTER(ctypes.c_char)
cs = RKIntegerToCommaStyleString(12345678)
ctypes.c_char_p.from_buffer(cs).value.decode('utf-8')
# Out:
# '12,345,678'
